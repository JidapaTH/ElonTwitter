# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
tsla = pd.read_csv("../../data/stock_price/TSLA.csv")

# %%
tsla.head()
# Out:
#          Date       Open   High        Low      Close  Adj Close    Volume
# 0  2010-06-29  19.000000  25.00  17.540001  23.889999  23.889999  18766300
# 1  2010-06-30  25.790001  30.42  23.299999  23.830000  23.830000  17187100
# 2  2010-07-01  25.000000  25.92  20.270000  21.959999  21.959999   8218800
# 3  2010-07-02  23.000000  23.10  18.709999  19.200001  19.200001   5139800
# 4  2010-07-06  20.000000  20.00  15.830000  16.110001  16.110001   6866900

# %%
tsla.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  2204.000000  2204.000000  2204.000000  2204.000000  2204.000000
# mean    176.132722   179.194950   172.888902   176.132972   176.132972
# std     115.491848   117.277472   113.571525   115.495920   115.495920
# min      16.139999    16.629999    14.980000    15.800000    15.800000
# 25%      33.137499    33.987502    32.530001    33.220001    33.220001
# 50%     205.550003   209.084999   202.500000   205.299995   205.299995
# 75%     262.399994   265.667511   257.804993   262.072502   262.072502
# max     386.690002   389.609985   379.350006   385.000000   385.000000
#
#              Volume
# count  2.204000e+03
# mean   5.093375e+06
# std    4.541442e+06
# min    1.185000e+05
# 25%    1.584300e+06
# 50%    4.193900e+06
# 75%    6.908300e+06
# max    3.716390e+07

# %%
# change date column into pandas datetime
tsla["Date"] = pd.to_datetime(tsla["Date"])

# %%
tsla['Date'][500]
# Out:
# Timestamp('2012-06-21 00:00:00')

# %%
x = tsla['Date']
y = tsla['Close']

# %%
# TSLA stock prices since IPO

fig, ax = plt.subplots(figsize=(20,10))
ax.plot(x, y)
ax.set_title('TSLA Price since IPO')
plt.show()

# %%
# exploring April Fool's Day over the years

fig, ax = plt.subplots(figsize=(20,10))
ax.plot(x, y)
ax.set_title('TSLA Price since IPO')
ax.set_xlim(('2016-01-01 00:00:00', '2019-04-10 00:00:00'))

ax.axvline(x='2013-04-01 00:00:00', color='red')
ax.axvline(x='2014-04-01 00:00:00', color='red')
ax.axvline(x='2015-04-01 00:00:00', color='red')
ax.axvline(x='2016-04-01 00:00:00', color='red')
ax.axvline(x='2017-04-01 00:00:00', color='red')
ax.axvline(x='2018-04-01 00:00:00', color='red')
ax.axvline(x='2019-04-01 00:00:00', color='red')

plt.show()

# %%
elon = pd.read_csv("../../data/twitter/elon_clean.csv")

# %%
elon.head()
# Out:
#    username              date  retweets  favorites  \
# 0  elonmusk  2019-04-02 20:38       993       9263
# 1  elonmusk  2019-04-02 20:16      7238      55271
# 2  elonmusk  2019-04-02 19:40       368       9159
# 3  elonmusk  2019-04-02 09:24      1317       6176
# 4  elonmusk  2019-04-02 09:21      1557      26925
#
#                                                 text mentions hashtags  \
# 0  Dogecoin value may vary https://www. theonion....      NaN      NaN
# 1           Dogecoin rulz pic.twitter.com/flWWUgAgLU      NaN      NaN
# 2                                              Uh oh      NaN      NaN
# 3  Dogecoin might be my fav cryptocurrency. It’s ...      NaN      NaN
# 4  Yup https:// twitter.com/nasa/status/11 128601...      NaN      NaN
#
#                                            permalink
# 0  https://twitter.com/elonmusk/status/1113178951...
# 1  https://twitter.com/elonmusk/status/1113173498...
# 2  https://twitter.com/elonmusk/status/1113164389...
# 3  https://twitter.com/elonmusk/status/1113009339...
# 4  https://twitter.com/elonmusk/status/1113008497...

# %%
# change date column into pandas datetime

elon["date"] = pd.to_datetime(elon["date"])

# %%
fig, ax1 = plt.subplots(figsize=(20,10))

x1 = tsla['Date']
y1 = tsla['Close']

ax1.set_title('TSLA Price vs Elon Tweet Counts', fontsize=30)

l1 = ax1.plot(x1,y1,color='blue')
ax1.set_ylabel('TSLA Stock Price',color='blue', fontsize=20)
ax1.tick_params('y', colors='blue', labelsize=15)
ax1.tick_params('x', labelsize=15)

x2 = elon["date"].sort_values(ascending=True)
y2 = list(range(1,len(elon["date"])+1))

ax2 = ax1.twinx() # create second axis for y2
l2, = ax2.plot(x2, y2, color='red')
ax2.set_ylabel('Elon Tweet Count',color='red', size=20)
ax2.tick_params('y', colors='red', labelsize=15)

plt.show()
